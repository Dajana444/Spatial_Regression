# %% [markdown]
# <a href="https://colab.research.google.com/github/Dajana444/Spatial_Regression/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geojson
# !pip install --upgrade geopandas
# !pip install ipfn

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
relative_risk = pd.read_csv("https://raw.githubusercontent.com/Dajana444/Spatial_Regression/main/map4.csv", encoding= 'unicode_escape')
relative_risk = relative_risk[["kommunenummer","SMR","RR"]]
relative_risk
# Out:
#      kommunenummer       SMR        RR
# 0              301  0.850217  0.935689
# 1             1101  1.083306  0.967057
# 2             1103  1.007519  0.970100
# 3             1106  1.017705  1.001719
# 4             1108  0.900952  0.974134
# ..             ...       ...       ...
# 351           5440  0.000000  0.836705
# 352           5441  0.540123  0.966636
# 353           5442  0.000000  0.840444
# 354           5443  0.000000  0.937716
# 355           5444  1.254206  0.916225
#
# [356 rows x 3 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ca3573a3-d22c-44a7-b453-13a95925aa2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca3573a3-d22c-44a7-b453-13a95925aa2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Kommuner.geojson to Kommuner.geojson

# %%
geodata = gpd.read_file("Kommuner.geojson")
geodata
# Out:
#      kommunenummer  ...                                           geometry
# 0             5020  ...  MULTIPOLYGON (((269579.990 7137979.000, 269522...
# 1             5022  ...  MULTIPOLYGON (((222840.270 6972994.330, 222850...
# 2             5021  ...  MULTIPOLYGON (((203841.430 6950369.520, 203842...
# 3             5028  ...  MULTIPOLYGON (((260161.904 7030526.216, 260161...
# 4             5027  ...  MULTIPOLYGON (((249316.800 6984449.450, 249275...
# ..             ...  ...                                                ...
# 351           5045  ...  MULTIPOLYGON (((361779.480 7150736.090, 361749...
# 352           1103  ...  MULTIPOLYGON (((-31804.000 6566440.000, -31811...
# 353           1106  ...  MULTIPOLYGON (((-58787.000 6629083.000, -58809...
# 354           5042  ...  MULTIPOLYGON (((449269.090 7189059.140, 448544...
# 355           5041  ...  MULTIPOLYGON (((412808.590 7108865.740, 412808...
#
# [356 rows x 3 columns]

# %%
# !pip install mapclassify

# %%
import mapclassify
import geopandas as gpd
import matplotlib.pyplot as plt
import holoviews.plotting as hvplot

# %%
relative_risk = pd.merge(geodata, relative_risk, on="kommunenummer")
relative_risk
# Out:
#      kommunenummer            navn  ...       SMR        RR
# 0             5020            Osen  ...  0.000000  0.950772
# 1             5022         Rennebu  ...  1.730129  0.950151
# 2             5021          Oppdal  ...  0.883168  1.029357
# 3             5028          Melhus  ...  0.800485  1.001119
# 4             5027  Midtre Gauldal  ...  1.115148  0.992803
# ..             ...             ...  ...       ...       ...
# 351           5045           Grong  ...  0.000000  1.022048
# 352           1103       Stavanger  ...  1.007519  0.970100
# 353           1106       Haugesund  ...  1.017705  1.001719
# 354           5042          Lierne  ...  0.000000  0.943959
# 355           5041           Snåsa  ...  1.007927  0.948185
#
# [356 rows x 5 columns]

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk.plot(column='SMR', scheme="Quantiles", k=5, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('Standard incidence rate map for digestive cancer')
plt.show()

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk.plot(column='RR', scheme="Quantiles", k=5, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('Reative risk map for digestive cancer')
plt.show()

# %%
relative_risk2 = pd.read_csv("https://raw.githubusercontent.com/Dajana444/Spatial_Regression/main/map5.csv", encoding= 'unicode_escape')
relative_risk2 = relative_risk2[["kommunenummer","SMR","RR"]]
relative_risk2
# Out:
#      kommunenummer       SMR        RR
# 0              301  0.971588  0.972159
# 1             1101  1.654503  1.578269
# 2             1103  1.331338  1.328609
# 3             1106  1.700943  1.672844
# 4             1108  1.267467  1.257488
# ..             ...       ...       ...
# 351           5440  0.000000  0.355288
# 352           5441  0.000000  0.183711
# 353           5442  0.000000  0.423383
# 354           5443  0.000000  0.215322
# 355           5444  1.755749  1.611844
#
# [356 rows x 3 columns]

# %%
relative_risk2 = pd.merge(geodata, relative_risk2, on="kommunenummer")
relative_risk2
# Out:
#      kommunenummer            navn  ...       SMR        RR
# 0             5020            Osen  ...  0.000000  0.493223
# 1             5022         Rennebu  ...  0.000000  0.271932
# 2             5021          Oppdal  ...  0.000000  0.147093
# 3             5028          Melhus  ...  0.000000  0.112203
# 4             5027  Midtre Gauldal  ...  0.000000  0.176984
# ..             ...             ...  ...       ...       ...
# 351           5045           Grong  ...  0.000000  0.257582
# 352           1103       Stavanger  ...  1.331338  1.328609
# 353           1106       Haugesund  ...  1.700943  1.672844
# 354           5042          Lierne  ...  0.000000  0.378404
# 355           5041           Snåsa  ...  0.000000  0.344921
#
# [356 rows x 5 columns]

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk2.plot(column='SMR', scheme="FisherJenks", k=4, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('The standard incidence rate mapping for lung cancer')
plt.show()

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk2.plot(column='RR', scheme="FisherJenks", k=4, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('The relative risk map for lung cancer')
plt.show()

# %%
relative_risk3 = pd.read_csv("https://raw.githubusercontent.com/Dajana444/Spatial_Regression/main/map7.csv", encoding= 'unicode_escape')
relative_risk3 = relative_risk3[["kommunenummer","SMR","RR"]]
relative_risk3
# Out:
#      kommunenummer       SMR        RR
# 0              301  0.828972  0.858508
# 1             1101  1.083757  0.981200
# 2             1103  1.026938  0.994380
# 3             1106  1.108250  1.071181
# 4             1108  0.904476  0.962221
# ..             ...       ...       ...
# 351           5440  1.225697  0.898842
# 352           5441  0.909826  1.050028
# 353           5442  1.053599  0.896786
# 354           5443  1.087663  1.025341
# 355           5444  0.979205  0.979994
#
# [356 rows x 3 columns]

# %%
relative_risk3 = pd.merge(geodata, relative_risk3, on="kommunenummer")
relative_risk3
# Out:
#      kommunenummer            navn  ...       SMR        RR
# 0             5020            Osen  ...  0.987570  0.974053
# 1             5022         Rennebu  ...  1.336261  0.946676
# 2             5021          Oppdal  ...  0.967844  1.038073
# 3             5028          Melhus  ...  0.852188  0.967375
# 4             5027  Midtre Gauldal  ...  0.963209  0.982130
# ..             ...             ...  ...       ...       ...
# 351           5045           Grong  ...  1.024734  1.059672
# 352           1103       Stavanger  ...  1.026938  0.994380
# 353           1106       Haugesund  ...  1.108250  1.071181
# 354           5042          Lierne  ...  1.387673  0.972150
# 355           5041           Snåsa  ...  1.230394  0.969014
#
# [356 rows x 5 columns]

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk3.plot(column='SMR', scheme="FisherJenks", k=5, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('The standard incidence rate mapping for all cancer types')
plt.show()

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
relative_risk3.plot(column='RR', scheme="Quantiles", k=5, ax=ax,
        edgecolor='grey', legend=True, cmap = "Reds", linewidth=0.3)
ax.set_axis_off()
ax.set_title('Relative risk map for all type cancers')
plt.show()
